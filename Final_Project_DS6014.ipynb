# %% [markdown]
# # Bayes Final Project: Spam Text Classifier

# %% [markdown]
# Approach: <br>
# In this project, we will use various Bayesian statistical methods to classify incoming texts as spam or ham based on the data given in the UCI machine learning repository. In each method, our approach makes use of a prior distribution on our model parameters and updates the parameters based on the evidence available in order to create a posterior distribution of parameters with propagated uncertainty accounted for.

# %% [markdown]
# ## Mounting Google Colab

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading data into pandas dataframe

# %%
# df = pd.read_csv("/content/drive/MyDrive/DS6014_Spam/SMSSpamCollection",sep='\t',names=["class","text"]) # Drive link
df = pd.read_csv("DS6014_Spam/SMSSpamCollection",sep='\t',names=["type","text"]) # deepnote

# %% [markdown]
# ### Statistics

# %%
print("Statistics")
print(79*"-")
print("General statistics")
display(df.describe( ))
print(79*"-")
print("Class Separation")
display(df.groupby("type").count())
# Out:
# Statistics
# -------------------------------------------------------------------------------
# General statistics
#         type                    text
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
# -------------------------------------------------------------------------------
# Class Separation
#       text
# type
# ham   4825
# spam   747

# %% [markdown]
# ### Creating Training and Testing Splits

# %%
from sklearn.model_selection import train_test_split
# balanced/stratified splits
train, test = train_test_split(df, test_size=0.10, random_state=42,stratify=df['type'])

# %% [markdown]
# ## Naive Bayes Classifier

# %% [markdown]
# ### Importing prerequisites

# %%
from project_code import NaiveBayesClassifier
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Train Model

# %%
naive = NaiveBayesClassifier(df,alpha=1.5) # call custom function to train model
naive.table_to_csv('DS6014_Spam/word_table.csv')
naive.prob_table.head()
# Out:
# Wrote to DS6014_Spam/word_table.csv!
# type       ham      spam
# word
# !     0.008421  0.014311
# #     0.002787  0.000196
# $     0.000202  0.000144
# %     0.000084  0.000118
# &     0.007356  0.004701
